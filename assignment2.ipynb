# %% [markdown]
# ## Assignment 2

# %% [markdown]
# ### Question 1:

# %% [markdown]
# #### i. Extract digits from roll number, multiply each by 10 to form list L and print L

# %%
roll_number = "1024170437"
L = [int(d) * 10 for d in roll_number]
print(L)
# Out:
# [10, 0, 20, 40, 10, 70, 0, 40, 30, 70]

# %% [markdown]
# #### ii. Add two numbers to L using append() and insert()

# %%
L.append(80)
print("After append:", L)
L.insert(2, 25)
print("After inserting at index 2:", L)
# Out:
# After append: [10, 0, 20, 40, 10, 70, 0, 40, 20, 80, 80]
# After inserting at index 2: [10, 0, 25, 20, 40, 10, 70, 0, 40, 20, 80, 80]

# %% [markdown]
# #### iii. Remove two elements from L using remove() and pop()

# %%
L.remove(25)
print("After removing 25 from list:", L)
L.pop()
print("After pop():", L)
# Out:
# After removing 25 from list: [10, 0, 20, 40, 10, 70, 0, 40, 20, 80, 80]
# After pop(): [10, 0, 20, 40, 10, 70, 0, 40, 20, 80]

# %% [markdown]
# #### iv. Sort L in ascending and descending order

# %%
L.sort()
print("list in ascending order:", L)
L.sort(reverse=True)
print("list in descending order:", L)
# Out:
# list in ascending order: [0, 0, 10, 10, 20, 20, 40, 40, 70, 80]
# list in descending order: [80, 70, 40, 40, 20, 20, 10, 10, 0, 0]

# %% [markdown]
# #### v. Slicing: first three elements and last three elements

# %%
print("First 3 :", L[:3])
print("Last 3 :", L[-3:])
# Out:
# First 3 : [80, 70, 40]
# Last 3 : [10, 0, 0]

# %% [markdown]
# #### vi. List comprehension for elements greater than average of L

# %%
avg = sum(L) / len(L)
print("Avg=", avg)
greaterthanavg = [i for i in L if i > avg]
print("Elements greater than avg", greaterthanavg)
# Out:
# Avg= 29.0
# Elements greater than avg [40, 70, 40, 30, 70]

# %% [markdown]
# ### Question 2: Tuples

# %% [markdown]
# #### Create tuple named scores using first 8 values from L in Q1

# %%
scores = tuple(L[:8])
print("tuple:", scores)
# Out:
# tuple: (10, 0, 20, 40, 10, 70, 0, 40)

# %% [markdown]
# #### i. Find highest score and its index, lowest score and its count

# %%
maxscore = max(scores)
maxindex = scores.index(maxscore)
minscore = min(scores)
mincount = scores.count(minscore)
print("Highest score:", maxscore, "at index:", maxindex)
print("Lowest score:", minscore, )
print("appears:", mincount, "times")
# Out:
# Highest score: 70 at index: 5
# Lowest score: 0
# appears: 2 times

# %% [markdown]
# #### ii. Reverse tuple and return as list

# %%
reversed_list = list(reversed(scores))
print("Reversed :", reversed_list)
# Out:
# Reversed : [40, 0, 70, 10, 40, 20, 0, 10]

# %% [markdown]
# #### iii. Ask user for a score and print its index or not present message

# %%
users = int(input("Enter a score: "))
if users in scores:
    print("Score found at index:", scores.index(users))
else:
    print("Score not present in tuple")
# Out:
# Score not present in tuple

# %% [markdown]
# #### iv. Attempt to change one element and capture error

# %%
try:
    scores[0] = 100
except TypeError as e:
    print("Caught error:", e)
# Out:
# Caught error: 'tuple' object does not support item assignment

# %% [markdown]
# #### v. Unpack tuple using * operator in a single line

# %%
first, second, *remainingscore = scores
print("First :", first)
print("Second :", second)
print("Remaining :", remainingscore)
# Out:
# First : 80
# Second : 70
# Remaining : [40, 40, 20, 20, 10, 10]

# %% [markdown]
# ### Question 3: Random Numbers & Seed

# %% [markdown]
# #### i. Generate list of 100 random numbers between 100 and 900 (inclusive)

# %%
import random
from collections import Counter

random.seed(1024170428)
randomnumber = [random.randint(100, 900) for i in range(100)]
print(randomnumber)
# Out:
# [443, 172, 518, 407, 476, 515, 856, 681, 664, 744, 416, 175, 195, 217, 529, 345, 512, 372, 850, 326, 442, 358, 599, 418, 648, 273, 681, 353, 195, 580, 564, 860, 635, 862, 668, 209, 623, 793, 441, 687, 831, 798, 665, 186, 814, 195, 396, 549, 254, 713, 133, 431, 710, 669, 113, 516, 615, 731, 540, 653, 539, 856, 676, 875, 393, 317, 374, 839, 205, 507, 585, 657, 627, 285, 743, 782, 410, 661, 435, 703, 571, 602, 643, 469, 504, 225, 700, 186, 237, 415, 260, 768, 520, 108, 333, 643, 873, 613, 395, 341]

# %% [markdown]
# #### ii. Count and print all odd numbers in the list

# %%
oddnumber = [x for x in randomnumber if x % 2 != 0]
print("Odd numbers count:", len(oddnumber))
print("Odd numbers:", oddnumber)
# Out:
# Odd numbers count: 59
# Odd numbers: [443, 407, 515, 681, 175, 195, 217, 529, 345, 599, 273, 681, 353, 195, 635, 209, 623, 793, 441, 687, 831, 665, 195, 549, 713, 133, 431, 669, 113, 615, 731, 653, 539, 875, 393, 317, 839, 205, 507, 585, 657, 627, 285, 743, 661, 435, 703, 571, 643, 469, 225, 237, 415, 333, 643, 873, 613, 395, 341]

# %% [markdown]
# #### iii. Count and print all even numbers in the list

# %%
evennumber = [x for x in randomnumber if x % 2 == 0]
print("Even numbers count:", len(evennumber))
print("Even numbers:", evennumber)
# Out:
# Even numbers count: 41
# Even numbers: [172, 518, 476, 856, 664, 744, 416, 512, 372, 850, 326, 442, 358, 418, 648, 580, 564, 860, 862, 668, 798, 186, 814, 396, 254, 710, 516, 540, 856, 676, 374, 782, 410, 602, 504, 700, 186, 260, 768, 520, 108]

# %% [markdown]
# #### iv. Count and print all prime numbers, and build list of prime numbers

# %%
def is_prime(n):
    if n < 2:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

primenumber = [x for x in randomnumber if is_prime(x)]
print("Prime numbers count:", len(primenumber))
print("Prime numbers:", primenumber)
# Out:
# Prime numbers count: 14
# Prime numbers: [443, 599, 353, 431, 113, 653, 317, 839, 743, 661, 571, 643, 643, 613]

# %% [markdown]
# #### v. Print the number that occurs most frequently and how many times it occurs

# %%
counts = Counter(randomnumber)
most_common_num, freq = counts.most_common(1)[0]
print("Most freq number:", most_common_num, "Freq:", freq)
# Out:
# Most freq number: 195 Freq: 3

# %% [markdown]
# ### Question 4: Sets

# %% [markdown]
# #### Create sets A and B from the first 8 digits of roll number

# %%
digits_8 = [int(d) for d in roll_number[:8]]
A = {d * 7 for d in digits_8}
B = {d * 9 for d in digits_8}
print("Set A:", A)
print("Set B:", B)
# Out:
# Set A: {0, 7, 14, 49, 28}
# Set B: {0, 36, 9, 18, 63}

# %% [markdown]
# #### vi. Find the union of A and B

# %%
print("Union:", A.union(B))
# Out:
# Union: {0, 36, 7, 9, 14, 49, 18, 28, 63}

# %% [markdown]
# #### vii. Find the intersection of A and B

# %%
print("Intersection:", A.intersection(B))
# Out:
# Intersection: {0}

# %% [markdown]
# #### viii. Find A - B and B - A using difference()

# %%
print("A - B:", A.difference(B))
print("B - A:", B.difference(A))
# Out:
# A - B: {49, 28, 14, 7}
# B - A: {9, 18, 36, 63}

# %% [markdown]
# #### ix. Find symmetric difference of A and B

# %%
print("Symmetric diff:", A.symmetric_difference(B))
# Out:
# Symmetric diff: {7, 9, 14, 18, 28, 36, 49, 63}

# %% [markdown]
# #### x. Check subset and superset using issubset() and issuperset()

# %%
print("Is A subset of B:", A.issubset(B))
print("Is B superset of A:", B.issuperset(A))
# Out:
# Is A subset of B: False
# Is B superset of A: False

# %% [markdown]
# #### xi. Remove X from set A using discard()

# %%
X = int(input("Enter value X: "))
A.discard(X)
print("A after discard:", A)
# Out:
# A after discard: {0, 7, 14, 49, 28}

# %% [markdown]
# ### Question 5: Dictionaries

# %% [markdown]
# #### Create initial dictionary

# %%
my_dict = {
    "name": "Hittin Gupta",
    "roll_no": "1024170437",
    "branch": "COPC",
    "age": 20,
    "city": "Patiala"
}
print(my_dict)
# Out:
# {'name': 'Hittin Gupta', 'roll_no': '1024170437', 'branch': 'COPC', 'age': 20, 'city': 'Patiala'}

# %% [markdown]
# #### i. Rename key city to location without changing its value

# %%
my_dict["location"] = my_dict.pop("city")
print(my_dict)
# Out:
# {'name': 'Hittin Gupta', 'roll_no': '1024170437', 'branch': 'COPC', 'age': 20, 'location': 'Patiala'}

# %% [markdown]
# #### ii. Add new key cgpa

# %%
my_dict["cgpa"] = 7.03
print(my_dict)
# Out:
# {'name': 'Hittin Gupta', 'roll_no': '1024170437', 'branch': 'COPC', 'age': 20, 'location': 'Patiala', 'cgpa': 7.03}

# %% [markdown]
# #### iii. Update age by increasing it by 1

# %%
my_dict["age"] += 6
print(my_dict)
# Out:
# {'name': 'Hittin Gupta', 'roll_no': '1024170437', 'branch': 'COPC', 'age': 26, 'location': 'Patiala', 'cgpa': 7.03}

# %% [markdown]
# #### iv. Delete branch key using pop() and del in separate copies

# %%
dict_copy1 = my_dict.copy()
dict_copy2 = my_dict.copy()

popped_val = dict_copy1.pop("branch")
print("dict  after pop():", dict_copy1)

del dict_copy2["branch"]
print("dict  after del:", dict_copy2)
# Out:
# dict  after pop(): {'name': 'Hittin Gupta', 'roll_no': '1024170437', 'age': 26, 'location': 'Patiala', 'cgpa': 7.03}
# dict  after del: {'name': 'Hittin Gupta', 'roll_no': '1024170437', 'age': 26, 'location': 'Patiala', 'cgpa': 7.03}

# %% [markdown]
# #### v. Iterate over dictionary using .items()

# %%
for key, value in my_dict.items():
    print(f"{key} -> {value}")
# Out:
# name -> Hittin Gupta
# roll_no -> 1024170437
# branch -> COPC
# age -> 26
# location -> Patiala
# cgpa -> 7.03

# %% [markdown]
# #### vi. Check for email key before accessing

# %%
if "email" in my_dict:
    print(my_dict["email"])
else:
    print("'email' does not exist in dictionary")
# Out:
# 'email' does not exist in dictionary

# %% [markdown]
# #### vii. Create friend_dict, merge using {**dict1, **dict2}

# %%
friend_dict = {
    "name": "DAnmol Bawa",
    "roll_no": "1024170432",
    "branch": "COPC",
    "age": 20,
    "location": "Patiala"
}

merged_dict = {**my_dict, **friend_dict}
print("Merged dictionary:", merged_dict)
# Out:
# Merged dictionary: {'name': 'DAnmol Bawa', 'roll_no': '1024170432', 'branch': 'COPC', 'age': 20, 'location': 'Patiala', 'cgpa': 7.03}

# %% [markdown]
# #### viii. Dictionary comprehension for string values only

# %%
string_only_dict = {k: v for k, v in my_dict.items() if isinstance(v, str)}
print(string_only_dict)
# Out:
# {'name': 'Hittin Gupta', 'roll_no': '1024170437', 'branch': 'COPC', 'location': 'Patiala'}
